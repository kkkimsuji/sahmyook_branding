# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 24 not upgraded.
# Need to get 9,599 kB of archives.
# After this operation, 29.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-nanum all 20180306-3 [9,599 kB]
# Fetched 9,599 kB in 2s (5,159 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family = 'NnumBarunGothic')

# %% [markdown]
# ### 애드캠퍼스 삼육대 학교미래 (2020.3.4~)
# 1. 유지 한다 : 47 (40.9%)
# 2.  발전 한다 : 43 (37.4%)
# 3.  퇴보 한다 : 25 (21.7%)

# %%
df= pd.read_csv('애드캠퍼스_재학생리뷰.csv')
df.head()
# Out:
#    추천/비추천          날짜   학번      학과                                    한줄평   \
# 0      비추천  2016.04.30  비공개     화학과      디자인과 다른 분위기인 원예학을 병행하는게 정말 죽을맛이에요
# 1      비추천  2016.04.30  비공개  생활체육학과              공대에서 배우는 총 집합체를 한곳에서 배우는곳
# 2       추천  2016.04.30  비공개   일본어학과  학교생활 하면서 영어에 갇힌 느낌. 영어가 안늘래야 안늘수가 없다.
# 3      비추천  2016.04.30  비공개    간호학과     배우는것이 흥미롭다. 항상 접해오던 것이라 실용적이기도 하다.
# 4       추천  2016.04.30  비공개  식품영양학과                   여자밭이다. 정말 여자뿐이다. 진짜로
#
#     총 만족도    시설    문화    대학가    등록금    교수   \
# 0        3     4     5      2      3     3
# 1        3     4     4      1      3     3
# 2        4     4     5      4      4     5
# 3        3     3     4      1      2     3
# 4        3     4     3      1      3     5
#
#                                                  장점   \
# 0        미래에 전망있는 환경과 최첨단 농업이라서 열심히 한 만큼 취업등에서 거둔다해요
# 1               여러가지 분야를 다 배우기 때문에 어디든 선택해서 갈 수가 있다.
# 2  영어에 가둬둔 느낌이다. 교수님들도 대부분이 한국어를 못하셔서 질문같은 사소한것도 ...
# ...

# %%
new_data = df.iloc[60:,:]
new_data
# Out:
#      추천/비추천            날짜   학번         학과   \
# 60       비추천    2020.03.04   18   아트앤디자인학과
# 61       비추천    2020.03.04  비공개       경영학과
# 62        추천    2020.03.04   18       간호학과
# 63       비추천    2020.03.04  비공개       경영학과
# 64       비추천    2020.03.04  비공개      일본어학과
# 65       비추천    2020.03.05  비공개   아트앤디자인학과
# 66        추천    2020.04.27  비공개       경영학과
# 67       비추천    2020.04.27   18   아트앤디자인학과
# 68       비추천    2020.04.28   17     영어영문학부
# 69        추천    2020.04.28  비공개     영어영문학부
# 70        추천    2020.04.28   19    화학생명과학과
# 71        추천    2020.04.28   18   동물생명자원학과
# 72        추천    2020.04.28   18   동물생명자원학과
# 73        추천    2020.04.28   18   동물생명자원학과
# 74       비추천    2020.04.28  비공개       경영학과
# 75        추천    2020.04.30   19     상담심리학과
# 76        추천    2020.05.01  비공개     물리치료학과
# 77        추천    2020.05.01   18      유아교육과
# 78        추천    2020.05.01   17    화학생명과학과
# 79        추천    2020.05.01   18     상담심리학과
# 80        추천  2020.05.0118   18      유아교육과
# ...

# %%
df[' 3년 후 학교의 미래 '].value_counts()
# Out:
# 유지 한다    47
# 발전 한다    43
# 퇴보 한다    25
# Name:  3년 후 학교의 미래 , dtype: int64

# %%
ratio = [25, 47, 43]
labels = ['bad', 'soso', 'good']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0b633a13c0>,
# ...
#  [Text(0.8532824353172374, 0.6941967196545118, 'bad'),
#   Text(-0.9696703199977601, 0.5193644871527524, 'soso'),
#   Text(0.42441952414360334, -1.0148241559628532, 'good')],
#  [Text(0.46542678290031125, 0.3786527561751882, '21.7%'),
#   Text(-0.5289110836351418, 0.28328972026513766, '40.9%'),
#   Text(0.2315015586237836, -0.5535404487070108, '37.4%')])
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# ...

# %% [markdown]
# ### 애드캠퍼스 가천대 학교미래 (2020.1.1~)
# 1. 발전한다 26 (47.3%)
# 2. 유지한다 24 (43.6%)
# 3. 퇴보한다 5 (9.1%)

# %% [markdown]
# 발전한다 3 유지한다 2 퇴보한다 1

# %%
g_future = '3133222223332333133322233322223311333222323232212332322'
g_m_future = '332332131333333333222333322'

# %%
print(g_m_future.count('1'))
print(g_m_future.count('2'))
print(g_m_future.count('3'))
# Out:
# 2
# 7
# 18

# %%
print(g_future.count('1'))
print(g_future.count('2'))
print(g_future.count('3'))
# Out:
# 5
# 24
# 26

# %%
# 가천대 글로벌
ratio = [5, 24, 26]
labels = ['bad', 'soso', 'good']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0b6555f340>,
# ...
#  [Text(1.0554422683381766, 0.30990582150899426, 'bad'),
#   Text(-0.3990884968250827, 1.0250504239801554, 'soso'),
#   Text(0.0941325223863866, -1.095964902827265, 'good')],
#  [Text(0.5756957827299144, 0.16903953900490593, '9.1%'),
#   Text(-0.21768463463186324, 0.5591184130800847, '43.6%'),
#   Text(0.05134501221075632, -0.5977990379057808, '47.3%')])
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# ...

# %%
# 가천대 메디컬
ratio = [2, 7, 18]
labels = ['bad', 'soso', 'good']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0b63472320>,
# ...
#  [Text(1.070349357197973, 0.2536774596724868, 'bad'),
#   Text(0.3154835705989099, 1.0537884591710818, 'soso'),
#   Text(-0.5499999702695119, -0.9526279613277874, 'good')],
#  [Text(0.5838269221079853, 0.13836952345772005, '7.4%'),
#   Text(0.17208194759940537, 0.5747937050024082, '25.9%'),
#   Text(-0.29999998378337006, -0.5196152516333385, '66.7%')])
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# ...

# %%
# 가천대 합산
ratio = [7, 31, 44]
labels = ['bad', 'soso', 'good']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0b634f7cd0>,
# ...
#  [Text(1.0606788444992425, 0.2914796542329362, 'bad'),
#   Text(-0.1679142064345156, 1.087108467116997, 'soso'),
#   Text(-0.1261516993157346, -1.092742306657774, 'good')],
#  [Text(0.5785520969995868, 0.15898890230887427, '8.5%'),
#   Text(-0.09158956714609941, 0.5929682547910893, '37.8%'),
#   Text(-0.06881001780858251, -0.5960412581769675, '53.7%')])
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# ...

# %% [markdown]
# ### 애드캠퍼스 한성대 학교미래 (2020.1.1~)
# 1. 발전한다 6 (46.2%)
# 2. 유지한다 6 (46.2%)
# 3. 퇴보한다 1 (7.7%)

# %%
h_future = '3223233123232'

# %%
h_future.count('1')
# Out:
# 1

# %%
h_future.count('2')
# Out:
# 6

# %%
h_future.count('3')
# Out:
# 6

# %%
ratio = [1, 6, 6]
labels = ['bad', 'soso', 'good']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbb8b094160>,
# ...
#  [Text(1.068035996798755, 0.26324724033138536, 'bad'),
#   Text(-0.3900654016728485, 1.0285178571214986, 'soso'),
#   Text(0.13259039153561472, -1.09197975625578, 'good')],
#  [Text(0.5825650891629571, 0.14358940381711927, '7.7%'),
#   Text(-0.21276294636700824, 0.5610097402480901, '46.2%'),
#   Text(0.07232203174669892, -0.5956253215940618, '46.2%')])
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# ...
