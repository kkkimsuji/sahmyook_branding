# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded
# /bin/bash: rm~/.cache/matplotlib: No such file or directory

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family = 'NnumBarunGothic')

# %% [markdown]
# # 2016년꺼 자른 데이터

# %%
data= pd.read_csv('애드캠퍼스_삼육대_재학생리뷰.csv', encoding = 'cp949')
data.head()
# Out:
#    추천/비추천          날짜   학번      학과                                    한줄평   \
# 0      비추천  2016.04.30  비공개     화학과      디자인과 다른 분위기인 원예학을 병행하는게 정말 죽을맛이에요
# 1      비추천  2016.04.30  비공개  생활체육학과              공대에서 배우는 총 집합체를 한곳에서 배우는곳
# 2       추천  2016.04.30  비공개   일본어학과  학교생활 하면서 영어에 갇힌 느낌. 영어가 안늘래야 안늘수가 없다.
# 3      비추천  2016.04.30  비공개    간호학과     배우는것이 흥미롭다. 항상 접해오던 것이라 실용적이기도 하다.
# 4       추천  2016.04.30  비공개  식품영양학과                   여자밭이다. 정말 여자뿐이다. 진짜로
#
#     총 만족도    시설    문화    대학가    등록금    교수   \
# 0        3     4     5      2      3     3
# 1        3     4     4      1      3     3
# 2        4     4     5      4      4     5
# 3        3     3     4      1      2     3
# 4        3     4     3      1      3     5
#
#                                                  장점   \
# 0        미래에 전망있는 환경과 최첨단 농업이라서 열심히 한 만큼 취업등에서 거둔다해요
# 1               여러가지 분야를 다 배우기 때문에 어디든 선택해서 갈 수가 있다.
# 2  영어에 가둬둔 느낌이다. 교수님들도 대부분이 한국어를 못하셔서 질문같은 사소한것도 ...
# 3  우선 취업분야가 다양하다. 우리 생활에 밀접하게 관련되어있는 식품에 대한 것들과 일...
# 4          식품에 대해 자세히 알 수 있다. 교수님들이 정말 다 좋으신 분들 뿐이다!
#
#                                                  단점   \
# 0  과제..디자인 과제만 하다보면 중간,기말이 다가와요 하지만 디자인 과제 때문에 원예...
# 1  반대로 여러가지 분야를 다 배우기 때문에 하나만 배우는 전공에 비해 전문성이 약간 낮다.
# 2     영어에 가둬둔게 장점이자 단점. 버티면 확실히 늘긴하는데 힘들어하는 사람들도 많다.
# 3  크게 문제가 될 만한 단점은 없는 것 같다. 다만 화학에 대해서도 알아야 하는데 그...
# 4  식품영양학과래서 왔더니 세상에 그냥 식품화학과다. 일반화학 유기화학 생화학 식품화학...
#
#                                           학교에 바라는 점   3년 후 학교의 미래
# 0                         과제좀 조금만 내줬으면 좋겠음. 솔직히 양심없음         발전 한다
# 1                   여자좀 많이 들어왔으면 좋겠고, 통폐합은 하지 않았으면..         퇴보 한다
# 2  이건 우리학부 뿐만 아니라 학교에다 바라는건데 학교가 너무 노잼입니다. 학지처는 각성하라         발전 한다
# 3  지금 배우는 것에 만족스럽게 다니고 있다. 하지만 보다 외우기 보다는 이해할 수 있...         발전 한다
# 4                학과보단 학교에 바라는 것이 있다. 식영과 지원 좀 팍팍 해줘라         발전 한다

# %%
new_data = data.iloc[26:,:]
new_data
# Out:
#      추천/비추천          날짜   학번         학과   \
# 26        추천  2017.01.04  비공개      유아교육과
# 27        추천  2017.01.08  비공개     보건관리학과
# 28        추천  2017.01.14  비공개       간호학과
# 29        추천  2017.01.16  비공개    미술컨텐츠학과
# 30        추천  2017.01.20  비공개     식품영양학과
# ..       ...         ...  ...        ...
# 110      비추천  2022.03.19  비공개       경영학과
# 111      비추천  2022.03.20  비공개       간호학과
# 112       추천  2022.04.30   22  항공관광외국어학부
# 113       추천  2022.08.28   20     보건관리학과
# 114      비추천  2023.11.21  비공개       간호학과
#
#                                                   한줄평    총 만족도    시설    문화   \
# 26     커리큘럼이 좋아서 실습갈 때 유용하다. 그리고 교수님들이 좋고, 학과 분위기가 좋다.        4     5     5
# 27                           공부하기 너무 힘들어요 다들 너무 열심히 한다        4     2     2
# 28                     종교에 거부감이 심하면 힘들수도. 쓸데 없는 과목이 많다        2     3     1
# 29                          정말 모든 맛보기로 배움 알아서 다 준비해야 함        5     2     5
# 30                                 영양사하고 싶으면 오세요….ㅋㅋㅋㅋ        3     2     1
# ..                                                 ...      ...   ...   ...
# 110                             종교색 짙고..인서울이 아닌 듯한 인서울        3     4     3
# 111                  인서울 끝자락 보건계열에서 나름대로 입지를 잡고 있는 대학교        4     4     4
# 112  항공관광외국어학부 리뷰이다. 신설학과라 아직 이곳에 있지 않아 일본어학과로 적게 되...        4     4     4
# 113                  보건계열에 흥미가 있다면 공부하기 좋아요-모두 열심히 합니다        4     4     4
# 114                       교회 안의 간호학과\n여기 올 성적이면 다른 대학가        2     3     1
#
#       대학가    등록금    교수                                                 장점   \
# 26       4      5     5  학생들 두루두루 잘 지내는 편임. 행사는 교구 전시. 스승의 날. 체육 대회. 학회...
# 27       2      3     5  학과장 교수님이 학생들을 정말 많이 생각해주신다수업시간 외에도 다양한 취업분야에 대...
# 28       1      2     3  모두 미친듯 공부를 한다. 덩달아 공부한다. 삼육병원이라는 안전빵이 있다. 과잠이 ...
# 29       2      1     5  그냥 프리하다....뭐....딱히 선배들 군기잡는 것도 없고 교수님도 굉장히 좋으신...
# 30       1      4     4  여초과이구,교수님이 좋음!!!!!!!!, 확실한 진로가 있는편(대부분 국가 고시후 ...
# ..     ...    ...   ...                                                ...
# 110      4      2     2  캠퍼스가 예쁩니다!\n인서울대하 치고는 성적대가 그리 높지 않아서 편하게 인서울 가...
# 111      3      4     3  보건계열 학과가 유명하고 캠퍼스 내부가 이쁘다.\n재단이 나름 튼튼하다. 종교적특색...
# 112      4      4     4  일본어, 중국어, 영어 세가지 언어 모두를 배울 수 있다는 점에서는 정말 좋은 학과...
# 113      4      4     4  전공 공부를 하면서 여러가지 자격증을 취득할 수 있다(보건의료정보관리사, 보건교육사...
# 114      1      2     1  캠퍼스가 넓다 근데 4월쯤 되면 더 이상 장점이 아니게 된다\n담배꽁초가 없다 \n...
#
#                                                    단점   \
# 26   난 딱히 불만이 없음. 1학년 때 토요일 채플이 있었는데 이제 토요일 채플도 사라져...
# 27   학과 봉사활동 동아리를 만들었음 좋겠습니다!사회복지학부 였다가 과가 생긴지 얼마 되...
# 28   종교(채플, 종교수업 채플은 맛난 간식 주니까 그나마 괜찮은데 종 교수업은 진짜 토...
# 29   학과 건물이 좀 많이 열악합니다..... 지원을 잘 안해주는지 교수님들이 항상 열심...
# 30   여초과, 단점이란 크게없다. 삼육대학교 어느학과이든 똑같겠지만 저학년이면 체육대회 ...
# ..                                                 ...
# 110  학식에 고기가 안 나오는 것도 그렇고 전반적으로 종교 강요 느낌을 받습니다.\n교수...
# 111  채플을 들어야한다. 금요일 학교 종교때문에 일찍 교내 시설이 운영을 종료한다는게 아...
# 112  가장 큰 단점은 생각하기로 종교로 인한 학식 문제라고 생각한다. \n별로 그런 것에...
# 113  20학번까지 보건의료정보관리사 자격증을 취득할 수 있다는 점이 아쉽다.\n학과 동아...
# 114  다른 종교대학들에 비해 종교 필수과목이 너무 많고 짜증난다. 그냥 재림교회 내부에 ...
#
#                                             학교에 바라는 점   3년 후 학교의 미래
# 26   학과 커뮤니티가 활성화되면 좋겠음. 싸이월드 클럽이 있긴 하지만 거기는 자료 올리는...         발전 한다
# 27   인원이 적은데 35명중에 학과 봉사활동 동아리를 만들었음 좋겠습니다!사회복지학부 였...         유지 한다
# 28   교수님 시험 좀 참신하게 내셨으면....족보본애들이랑 안본애들이랑 차 이나고 박탈감...         유지 한다
# 29   전문적으로 파고 들어가는게 있었으면 좋겠단 생각을 항상 하고있습니다. 우리과 너무 ...         퇴보 한다
# 30   없음.아무생각없이 학교를 다니고 있지만 학교에만 불만임 자유로운 영혼이라면 종교개입...         유지 한다
# ..                                                 ...           ...
# 110                                    기숙사 규정 좀 풀어주셨으면         발전 한다
# 111  종교계열 대학교라 학교의 전체적인 학칙이나 부분들을 고치기에는 현실적으로 불가능할것...         유지 한다
# 112  바울관 강의실마다 에어컨 설치 부탁드립니다. 정말 여름에는 너무 덥고, 사람이 많으...         유지 한다
# 113          다양한 학과 동아리를 만들어 취업 등 정보를 공유할 수 있으면 좋겠습니다!         유지 한다
# 114  다른 종교대학들 특히 가톨릭계열 대학들은 종교강요 없다는데 여긴 왜 이따구 인지. ...         유지 한다
#
# [89 rows x 15 columns]

# %%
new_data[' 추천/비추천 '] = new_data[' 추천/비추천 '].str.strip()
new_data[' 추천/비추천 '].unique()
# Out:
# <ipython-input-9-c20878eca12f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data[' 추천/비추천 '] = new_data[' 추천/비추천 '].str.strip()
# array(['추천', '비추천'], dtype=object)

# %%
new_data[' 추천/비추천 '].value_counts()
# Out:
# 추천     57
# 비추천    32
# Name:  추천/비추천 , dtype: int64

# %%
new_df_re = new_data[' 추천/비추천 '].value_counts()
plt.pie(new_df_re, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f996d1417f0>,
#   <matplotlib.patches.Wedge at 0x7f996d141700>],
#  [Text(-0.4697621643687211, 0.9946474294581045, ''),
#   Text(0.46976225749433254, -0.994647385475792, '')],
#  [Text(-0.2562339078374842, 0.5425349615226024, '64.0%'),
#   Text(0.25623395863327225, -0.5425349375322501, '36.0%')])
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.

# %% [markdown]
# # 모든 데이터

# %%
df= pd.read_csv('애드캠퍼스_삼육대_재학생리뷰.csv')
df.head()
# Out:
#    추천/비추천          날짜   학번      학과                                    한줄평   \
# 0      비추천  2016.04.30  비공개     화학과      디자인과 다른 분위기인 원예학을 병행하는게 정말 죽을맛이에요
# 1      비추천  2016.04.30  비공개  생활체육학과              공대에서 배우는 총 집합체를 한곳에서 배우는곳
# 2       추천  2016.04.30  비공개   일본어학과  학교생활 하면서 영어에 갇힌 느낌. 영어가 안늘래야 안늘수가 없다.
# 3      비추천  2016.04.30  비공개    간호학과     배우는것이 흥미롭다. 항상 접해오던 것이라 실용적이기도 하다.
# 4       추천  2016.04.30  비공개  식품영양학과                   여자밭이다. 정말 여자뿐이다. 진짜로
#
#     총 만족도    시설    문화    대학가    등록금    교수   \
# 0        3     4     5      2      3     3
# 1        3     4     4      1      3     3
# 2        4     4     5      4      4     5
# 3        3     3     4      1      2     3
# 4        3     4     3      1      3     5
#
#                                                  장점   \
# 0        미래에 전망있는 환경과 최첨단 농업이라서 열심히 한 만큼 취업등에서 거둔다해요
# 1               여러가지 분야를 다 배우기 때문에 어디든 선택해서 갈 수가 있다.
# 2  영어에 가둬둔 느낌이다. 교수님들도 대부분이 한국어를 못하셔서 질문같은 사소한것도 ...
# 3  우선 취업분야가 다양하다. 우리 생활에 밀접하게 관련되어있는 식품에 대한 것들과 일...
# 4          식품에 대해 자세히 알 수 있다. 교수님들이 정말 다 좋으신 분들 뿐이다!
#
#                                                  단점   \
# 0  과제..디자인 과제만 하다보면 중간,기말이 다가와요 하지만 디자인 과제 때문에 원예...
# 1  반대로 여러가지 분야를 다 배우기 때문에 하나만 배우는 전공에 비해 전문성이 약간 낮다.
# 2     영어에 가둬둔게 장점이자 단점. 버티면 확실히 늘긴하는데 힘들어하는 사람들도 많다.
# 3  크게 문제가 될 만한 단점은 없는 것 같다. 다만 화학에 대해서도 알아야 하는데 그...
# 4  식품영양학과래서 왔더니 세상에 그냥 식품화학과다. 일반화학 유기화학 생화학 식품화학...
#
#                                           학교에 바라는 점   3년 후 학교의 미래
# 0                         과제좀 조금만 내줬으면 좋겠음. 솔직히 양심없음         발전 한다
# 1                   여자좀 많이 들어왔으면 좋겠고, 통폐합은 하지 않았으면..         퇴보 한다
# 2  이건 우리학부 뿐만 아니라 학교에다 바라는건데 학교가 너무 노잼입니다. 학지처는 각성하라         발전 한다
# 3  지금 배우는 것에 만족스럽게 다니고 있다. 하지만 보다 외우기 보다는 이해할 수 있...         발전 한다
# 4                학과보단 학교에 바라는 것이 있다. 식영과 지원 좀 팍팍 해줘라         발전 한다

# %%
df.isnull().sum()
# Out:
#  추천/비추천          0
#  날짜              0
#  학번              0
#  학과              0
#  한줄평             0
#  총 만족도           0
#  시설              0
#  문화              0
#  대학가             0
#  등록금             0
#  교수              0
#  장점              0
#  단점              0
#  학교에 바라는 점       0
#  3년 후 학교의 미래     0
# dtype: int64

# %%
df.columns
# Out:
# Index([' 추천/비추천 ', ' 날짜 ', ' 학번 ', ' 학과 ', ' 한줄평 ', ' 총 만족도 ', ' 시설 ', ' 문화 ',
#        ' 대학가 ', ' 등록금 ', ' 교수 ', ' 장점 ', ' 단점 ', ' 학교에 바라는 점 ',
#        ' 3년 후 학교의 미래 '],
#       dtype='object')

# %% [markdown]
# # 추천/비추천 비율
# 추천 : 72 (62.6%)
# 비추천 : 43 (37.4%)
# ![image.png](data:image/png;base64,...)

# %%
df[' 추천/비추천 '] = df[' 추천/비추천 '].str.strip()
df[' 추천/비추천 '].unique()
# Out:
# array(['비추천', '추천'], dtype=object)

# %%
df_re = df[' 추천/비추천 '].value_counts()
plt.pie(df_re, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f1f6b555dc0>,
#   <matplotlib.patches.Wedge at 0x7f1f6b555cd0>],
#  [Text(-0.42441961915829607, 1.0148241162258251, ''),
#   Text(0.4244196191582961, -1.0148241162258251, '')],
#  [Text(-0.23150161044997963, 0.5535404270322682, '62.6%'),
#   Text(0.2315016104499797, -0.5535404270322681, '37.4%')])
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.

# %%
df[' 추천/비추천 '].value_counts()
# Out:
# 추천     72
# 비추천    43
# Name:  추천/비추천 , dtype: int64

# %% [markdown]
# # 3년 후 학교 미래 퍼센트
# * 유지 한다 :   47 (40.9%)
# * 발전 한다 :   43 (37.4%)
# * 퇴보 한다 :   25 (21.7%)
#
# ![image.png](data:image/png;base64,...)

# %%
df[' 3년 후 학교의 미래 '].unique()
# Out:
# array(['발전 한다', '퇴보 한다', '유지 한다'], dtype=object)

# %%
df[' 3년 후 학교의 미래 '].value_counts()
# Out:
# 유지 한다    47
# 발전 한다    43
# 퇴보 한다    25
# Name:  3년 후 학교의 미래 , dtype: int64

# %%
df_future = df[' 3년 후 학교의 미래 '].value_counts()
plt.pie(df_future, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f1f38c02eb0>,
#   <matplotlib.patches.Wedge at 0x7f1f38c02dc0>,
#   <matplotlib.patches.Wedge at 0x7f1f38c12be0>],
#  [Text(0.3112162005529939, 1.0550566224205025, ''),
#   Text(-0.907247450802346, -0.6220145199371515, ''),
#   Text(0.8532823703218457, -0.6941967995445762, '')],
#  [Text(0.16975429121072394, 0.5754854304111832, '40.9%'),
#   Text(-0.49486224589218863, -0.33928064723844625, '37.4%'),
#   Text(0.46542674744827944, -0.378652799751587, '21.7%')])
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NnumBarunGothic' not found.

# %% [markdown]
# # 형태소 *분석*

# %%
# 빈도수
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 68.4 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.22.4)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 41.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %%
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# ## 장점 분석

# %%
good_text = ''
for temp in df[' 장점 ']:
    good_text += str(temp)
good_text = re.sub(r'[^가-힣a-zA-Z0-9]',' ',good_text)
good_text
# Out:
# '미래에 전망있는 환경과 최첨단 농업이라서 열심히 한 만큼 취업등에서 거둔다해요여러가지 분야를 다 배우기 때문에 어디든 선택해서 갈 수가 있다 영어에 가둬둔 느낌이다  교수님들도 대부분이 한국어를 못하셔서 질문같은 사소한것도 영어로 해야함  물론 출석도 영어이름으로 부른다  선배들도 다 착하고 군기 그런건 전혀없다 오히려 자유로움우선 취업분야가 다양하다  우리 생활에 밀접하게 관련되어있는 식품에 대한 것들과 일상생활에 
학교에 비해 어떨지는 모르겠지만  적어도 막장으로 수업하시는 일은 없을거라 보장해 드립니다  초청되어 오시는 강사 교수님들도 대부분 꽤 좋은 분들이지만  그렇지 않은 교수도 꽤 있는 편입니다  다양한 미술 수업을 배울 수 있습니다  판화  서양화  동양화  도예  디자인 기타 등등   장점   솔직히 장점 없다고 생각하는데 그래도 꾸역꾸역 적어본다면 요새 문제되는 똥군기 이딴거 없다 왜냐하면 다들 개인플레이고 학과 생이 제일 많아서 누가 누군지도 모른다 1 2학년 전공수업 같은 경 우에는 바울관에서 듣는 경우가 많기 때문에 바쁠때 학식먹으러 가기가 편하다 정말정말 쥐어짜내는데도 장점이라곤 생각이 안나는 그지 같은 학과지만 한줄기 빛같은 교수님이 계시니    회계과목에서 원탑인 교수님이 계시는데 그분 수업은 정말 최고이다 항간에서는 이 교수 님을 갓트이라고 부르기도 한다 성격도 유하면서 재밌으시다 만약 회계나 세무쪽에 관심이 있다면 이 교수님에게 도움을 청해보는 것이 좋다체육과 치고는 남 녀비율이 반반으로 무거운분위기가 없고 전학년 두루두루 다소 화기애애함 좋은 시설로 다양한 체육시설이 있고 외부수업도 다수 있어 나쁘지는    않음 체대지만 생각보다 집합이나 구타등이 적음 저때는 많았    일단 대학교 입학하기 전에 걱정했던 똥군기 뭐 그런 건 전혀 없어요    오히려 언니들을 보는 게 너무 귀엽고 예쁜정도     진짜 유아교육과 오시면 알겠지만 언니들 진짜 예쁘게 생겼거든요         저희끼리 막 너무 예쁘다고 매일 난리치는데 진짜로요  유아교육과가 쓰는 건물이 제1실습관이라서 언니들 보면 꼭꼭인사하라고 하셨는데 그게 군 ...

# %%
# Okt 함수를 이용해 형태소 분석
okt = Okt()
g_line =[]

g_line = okt.pos(good_text)

print(g_line)

n_adj =[]
# 명사 또는 형용사인 단어만 n_adj에 넣어주기
for word, tag in g_line:
    if tag in ['Noun','Adjective']:
        if len(word) > 1:
            n_adj.append(word)
# 명사 또는 형용사인 단어 및 2글자 이상인 단어 선택 시
# n_adj = [word for wor
# Out:
# [('미래', 'Noun'), ('에', 'Josa'), ('전망', 'Noun'), ('있는', 'Adjective'), ('환경', 'Noun'), ('과', 'Josa'), ('최첨단', 'Noun'), ('농업', 'Noun'), ('이라서', 'Josa'), ('열심히', 'Adverb'), ('한', 'Verb'), ('만큼', 'Noun'), ('취업', 'Noun'), ('등', 'Noun'), ('에서', 'Josa'), ('거둔', 'Verb'), ('다해', 'Noun'), ('요', 'Josa'), ('여러가지', 'Noun'), ('분야', 'Noun'), ('를', 'Josa'), ('다', 'Adverb'), ('배우기', 'Verb'), ('때문', 'Noun'), ('에', 'Josa'), ('어디', 'Noun'), ('든', 'Josa'), ('선택', 'Noun'), ('해서', 'Verb'), ('갈', 'Verb'), ('수가', 'Noun'), ('있다', 'Adjective'), ('영어', 'Noun'), ('에', 'Josa'), ('가둬', 'Verb'), ('둔', 'Verb'), ('느낌', 'Noun'), ('이다', 'Josa'), ('교수', 'Noun'), ('님', 'Suffix'), ('들도', 'Verb'), ('대부분', 'Noun'), ('이', 'Josa'), ('한국어', 'Noun'), ('를', 'Josa'), ('못', 'VerbPrefix'), ('하셔서', 'Verb'), ('질문', 'Noun'), ('같은', 'Adjective'), ('사소한것도', 'Adjective'), ('영어', 'Noun'), ('로', 'Josa'), ('해야', 'Verb'), ('함', 'Noun'), ('물론', 'Adverb'), ('출석', 'Noun'), ('도', 'Josa'), ('영어', 'Noun'), ('이름', 'Noun'), ('으로', 'Josa'), ('부른다', 'Verb'), ('선배', 'Noun'), ('들', 'Suffix'), ('도', 'Josa'), ('다', 'Adverb'), ('착하고', 'Adjective'), ('군기', 'Noun'), ('그런건', 'Adjective'), ('전혀', 'Noun'), ('없다', 'Adjective'), ('오히려', 'Noun'), ('자유', 'Noun'), ('로움', 'Noun'), ('우선', 'Noun'), ('취업', 'Noun'), ('분야', 'Noun'), ('가', 'Josa'), ('다양하다', 'Adjective'), ('우리', 'Noun'), ('생활', 'Noun'), ('에', 'Josa'), ('밀접하게', 'Adjective'), ('관련', 'Noun'), ('되어있는', 'Verb'), ('식품', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('것', 'Noun'), ('들', 'Suffix'), ('과', 'Josa'), ('일상생활', 'Noun'), ('에', 'Josa'), ('도움', 'Noun'), ('이', 'Josa'), ('되는', 'Verb'), ('영양학', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('모든', 'Noun'), ('면', 'Noun'), ('에서', 'Josa'), ('학습', 'Noun'), ('하는', 'Verb'), ('것', 'Noun'), ('이기', 'Noun'), ('때문', 'Noun'), ('에', 'Josa'), ('흥미롭게', 'Adjective'), ('배울', 'Verb'), ('수', 'Noun'), ('있고', 'Adjective'), ('실용', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('학문', 'Noun'), ('이라는', 'Josa'), ('장점', 'Noun'), ('이', 'Josa'), ('있다', 'Adjective'), ('식품', 'Noun'), ('에', 'Josa'), ('대해', 'Noun'), ('자세히', 'Adjective'), ('알', 'Noun'), ('수', 'Noun'), ('있다', 'Adjective'), ('교수', 'Noun'), ('님', 'Suffix'), ('들이', 'Verb'), ('정말', 'Noun'), ('다', 'Adverb'), ('좋으신', 'Adjective'), ('분들', 'Suffix'), ('뿐', 'Noun'), ('이다', 'Josa'), ('사람', 'Noun'), ('이', 'Josa'), ('살아가는', 'Verb'), ('데', 'Noun'), ('있어', 'Adjective'), ('일명', 'Noun'), ('먹고', 'Verb'), ('싸는', 'Verb'), ('일이', 'Modifier'), ('가장', 'Noun'), ('중요하죠', 'Adjective'), ('이러한', 'Adjective'), ('것', 'Noun'), ('들', 'Suffix'), ('에', 'Josa'), ('있어', 'Adjective'), ('전문', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('지식', 'Noun'), ('을', 'Josa'), ('가지', 'Noun'), ('고', 'Josa'), ('활용', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있다는것이', 'Adjective'), ('식품', 'Noun'), ('영양학', 'Noun'), ('과의', 'Josa'), ('최대', 'Noun'), ('메리트', 'Noun'), ('죠', 'Josa'), ('현미경', 'Noun'), ('봄', 'Noun'), ('매', 'Modifier'), ('주', 'Modifier'), ('봄', 'Noun'), ('원한다면', 'Adjective'), ('매', 'Modifier'), ('일', 'Modifier'), ('봄', 'Noun'), ('피트', 'Noun'), ('로', 'Josa'), ('빠질려고', 'Verb'), ('하는', 'Verb'), ('학과', 'Noun'), ('생', 'Noun'), ('넘쳐서', 'Adjective'), ('공부', 'Noun'), ('열기', 'Noun'), ('불탐', 'Adjective'), ('과제', 'Noun'), ('는', 'Josa'), ('적당하고', 'Adjective'), ('팀플', 'Noun'), ('도', 'Josa'), ('적은', 'Verb'), ('편', 'Noun'), ('아무래도', 'Adverb'), ('일상생활', 'Noun'), ('에', 'Josa'), ('접목', 'Noun'), ('되어있는', 'Verb'), ('분야', 'Noun'), ('이다', 'Josa'), ('보니', 'Verb'), ('배우면서', 'Verb'), ('아', 'Exclamation'), ('그래서', 'Adverb'), ('그렇구나', 'Adjective'), ('하며', 'Verb'), ('느끼는', 'Verb'), ('점도', 'Noun'), ('많고', 'Adjective'), ('알아가면', 'Verb'), ('굉장히', 'Adjective'), ('유용한', 'Adjective'), ('것', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('많다', 'Adjective'), ('식품', 'Noun'), ('관련', 'Noun'), ('이다', 'Josa'), ('보니', 'Verb'), ('재미', 'Noun'), ('가', 'Josa'), ('없이', 'Adverb'), ('배울', 'Verb'), ('수', 'Noun'), ('는', 'Josa'), ('없는', 'Adjective'), ('것', 'Noun'), ('같다', 'Adjective'), ('흔히', 'Adjective'), ('말', 'Noun'), ('하는', 'Verb'), ('선배', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('군기', 'N ...

# %%
#제외할 단어 추가
stop_words = "삼육대 장점 교수 학교 학과 좋다 있다 좋은" #추가할 때 띄어쓰기로 추가해주기
stop_words = set(stop_words.split(' '))
# 불용어를 제외한 단어만 남기기
n_adj = [word for word in n_adj if not word in stop_words]
n_adj
#가장 많이 나온 단어 100개 저장
counts = Counter(n_adj)
tags = counts.most_common(100)
tags
# Out:
# [('수업', 38),
#  ('없다', 33),
#  ('생각', 30),
#  ('취업', 27),
#  ('정말', 27),
#  ('군기', 26),
#  ('분위기', 24),
#  ('서울', 23),
#  ('선배', 21),
#  ('굉장히', 18),
#  ('학생', 18),
#  ('있는', 17),
#  ('때문', 17),
#  ('종교', 17),
#  ('사람', 16),
#  ('공부', 16),
#  ('다양한', 16),
#  ('있고', 14),
#  ('전공', 14),
#  ('우리', 13),
#  ('지원', 13),
#  ('좋음', 13),
#  ('대부분', 12),
#  ('캠퍼스', 12),
#  ('정도', 12),
#  ('없고', 12),
#  ('대학교', 12),
#  ('일단', 12),
#  ('분야', 11),
#  ('같은', 11),
#  ('전혀', 11),
#  ('강요', 11),
#  ('병원', 11),
#  ('대학', 11),
#  ('많은', 10),
#  ('커리큘럼', 10),
#  ('진짜', 10),
#  ('자체', 10),
#  ('같다', 9),
#  ('다른', 9),
#  ('매우', 9),
#  ('시설', 9),
#  ('디자인', 9),
#  ('있음', 9),
#  ('있어서', 9),
#  ('실습', 9),
#  ('영어', 8),
#  ('친구', 8),
#  ('학점', 8),
#  ('보건', 8),
#  ('그냥', 8),
#  ('편이', 8),
#  ('환경', 7),
#  ('느낌', 7),
#  ('생활', 7),
#  ('대한', 7),
#  ('많다', 7),
#  ('끼리', 7),
#  ('취업률', 7),
#  ('같음', 7),
#  ('선후배', 7),
#  ('담배', 7),
#  ('걱정', 7),
#  ('시간', 7),
#  ('교육', 7),
#  ('진로', 7),
#  ('있습니다', 7),
#  ('없음', 7),
#  ('나름', 7),
#  ('열정', 7),
#  ('축산', 7),
#  ('만큼', 6),
#  ('도움', 6),
#  ('학문', 6),
#  ('없는', 6),
#  ('입니다', 6),
#  ('별로', 6),
#  ('공기', 6),
#  ('행사', 6),
#  ('계열', 6),
#  ('성적', 6),
#  ('인사', 6),
#  ('보고', 6),
#  ('문제', 6),
#  ('거의', 6),
#  ('있기', 6),
#  ('상담', 6),
#  ('여러가지', 5),
#  ('이름', 5),
#  ('관련', 5),
#  ('식품', 5),
#  ('대해', 5),
#  ('있어', 5),
#  ('가장', 5),
#  ('가지', 5),
#  ('중독', 5),
#  ('있어요', 5),
#  ('높은', 5),
#  ('좋고', 5),
#  ('그런지', 5)]

# %%
path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
word_cloud = WordCloud(font_path=path, background_color='black',max_font_size=400,colormap='coolwarm').generate_from_frequencies(dict(tags))

# 사이즈 설정 및 화면에 출력
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.imshow(word_cloud)
plt.axis('off')
#워드클라우드 사진으로 저장
plt.savefig('애드캠퍼스_장점.png', bbox_inches='tight')
plt.show()

# %%
df[df[' 장점 '].str.contains('교수')]

# %% [markdown]
# ## 단점

# %%
bad_text = ''
for temp in df[' 단점 ']:
    bad_text += str(temp)
bad_text = re.sub(r'[^가-힣a-zA-Z0-9]',' ',bad_text)
bad_text
# Out:
# '과제  디자인 과제만 하다보면 중간 기말이 다가와요 하지만 디자인 과제 때문에 원예학 공부는 절대 못해요 반대로 여러가지 분야를 다 배우기 때문에 하나만 배우는 전공에 비해 전문성이 약간 낮다 영어에 가둬둔게 장점이자 단점  버티면 확실히 늘긴하는데 힘들어하는 사람들도 많다 크게 문제가 될 만한 단점은 없는 것 같다  다만 화학에 대해서도 알아야 하는데 그 부분을 배울때면 나의 전공이 식품영양인지 화학과인지 헷갈리기도 한다 식품영양학과래서 왔더니 세상에 그냥 식품화학과다  일반화학 유기화학 생화학 식품화학 등등 화학이 안쓰이는 곳이 없다대학교에 공부만 하다 졸업하고 취업하러 온것만이 아닌데 남자가 없네요 이리봐도 저리봐도 남자가 남자사람이없네요피트생들 공부잘함  정말 많이 잘함  피트 과목에 생물 있어서 그런지 수업 안들어도 이미 알고 있음  외울거 많음 애매한 학과라서 인체도 배우고 동물도 배우고 식물도 배움  얕게 많이 배운다고 알면 클남  물리 치료학과 만큼 근육과 뼈를 외움 여자가 너무 많다 너무 어려운 내용을 많이 배우고  의대에 온건지 간호학과인지 보건관리학관지 알 수 가 없다 잘 모르겠습니다정문에서 조금 먼 위치의 과학관  과보다는 학교에 대한 불만이 클거에요학과보단 학교의 단점이 너무 크다  종교적 색채가 너무 뚜렷하고 간판이  체육대회에 목숨건다디자인 원예과라서 과제 많아요 미술과제도 있고 식물과제도 있음전공 수강 신청이 힘들다 커리큘럼이 좋지 않다 
온 건 맞는데  어느새 저처럼 아무생각없이 졸업반을 맞이하는 마법을 맛볼 수 있습니다  깊게 배우고 싶은 학생들은 진즉에 재수  편입을 하거나 아예 자퇴해 자기만의 길을 떠난 학생들도 적지 않습니다  자기가 하고 싶은걸 찾아서 휴학하는 경우도 꽤 있습니다  깊게 배울 수 없으니 오죽하면 상담을 해 주신 담당 교수님마저 교류학점을 해보라는 말씀이 나오실 정도입니다 자신이 미술을 하고 싶어서 온 건 맞는데  어느새 저처럼 아무생각없이 졸업반을 맞이하는 마법을 맛볼 수 있습니다 단합이 되질 않는다 우리 학과에서 군기가 절대 생길 수 없는 구조의 이유중 하나입니다 솔직히 제 입장에서는 이런면이 좋다고 느꼈는데 이번에 학과애들이 랑 좀 만나면서 이 ...

# %%
# Okt 함수를 이용해 형태소 분석
okt = Okt()
b_line =[]

b_line = okt.pos(bad_text)

print(b_line)

n_adj =[]
# 명사 또는 형용사인 단어만 n_adj에 넣어주기
for word, tag in b_line:
    if tag in ['Noun','Adjective']:
        if len(word) > 1:
            n_adj.append(word)
# Out:
# [('과제', 'Noun'), ('디자인', 'Noun'), ('과제', 'Noun'), ('만', 'Josa'), ('하다', 'Verb'), ('보면', 'Verb'), ('중간', 'Noun'), ('기', 'Modifier'), ('말', 'Noun'), ('이', 'Josa'), ('다가와요', 'Verb'), ('하지만', 'Conjunction'), ('디자인', 'Noun'), ('과제', 'Noun'), ('때문', 'Noun'), ('에', 'Josa'), ('원예학', 'Noun'), ('공부', 'Noun'), ('는', 'Josa'), ('절대', 'Noun'), ('못', 'VerbPrefix'), ('해요', 'Verb'), ('반대', 'Noun'), ('로', 'Josa'), ('여러가지', 'Noun'), ('분야', 'Noun'), ('를', 'Josa'), ('다', 'Adverb'), ('배우기', 'Verb'), ('때문', 'Noun'), ('에', 'Josa'), ('하나', 'Noun'), ('만', 'Josa'), ('배우는', 'Verb'), ('전공', 'Noun'), ('에', 'Josa'), ('비해', 'Verb'), ('전문성', 'Noun'), ('이', 'Josa'), ('약간', 'Noun'), ('낮다', 'Adjective'), ('영어', 'Noun'), ('에', 'Josa'), ('가둬', 'Verb'), ('둔게', 'Verb'), ('장점', 'Noun'), ('이자', 'Noun'), ('단점', 'Noun'), ('버티면', 'Verb'), ('확실히', 'Adjective'), ('늘긴', 'Verb'), ('하는데', 'Verb'), ('힘들어하는', 'Adjective'), ('사람', 'Noun'), ('들', 'Suffix'), ('도', 'Josa'), ('많다', 'Adjective'), ('크게', 'Noun'), ('문제', 'Noun'), ('가', 'Josa'), ('될', 'Verb'), ('만', 'Noun'), ('한', 'Josa'), ('단점', 'Noun'), ('은', 'Josa'), ('없는', 'Adjective'), ('것', 'Noun'), ('같다', 'Adjective'), ('다만', 'Noun'), ('화학', 'Noun'), ('에', 'Josa'), ('대해', 'Noun'), ('서도', 'Noun'), ('알아야', 'Verb'), ('하는데', 'Verb'), ('그', 'Noun'), ('부분', 'Noun'), ('을', 'Josa'), ('배울', 'Verb'), ('때', 'Noun'), ('면', 'Josa'), ('나', 'Noun'), ('의', 'Josa'), ('전공', 'Noun'), ('이', 'Josa'), ('식품', 'Noun'), ('영양', 'Noun'), ('인지', 'Josa'), ('화학', 'Noun'), ('과', 'Josa'), ('인지', 'Noun'), ('헷갈리', 'Adjective'), ('기도', 'Noun'), ('한다', 'Verb'), ('식품', 'Noun'), ('영양학', 'Noun'), ('과', 'Josa'), ('래서', 'Noun'), ('왔더니', 'Verb'), ('세상', 'Noun'), ('에', 'Josa'), ('그냥', 'Noun'), ('식품화학', 'Noun'), ('과', 'Noun'), ('다', 'Josa'), ('일반화학', 'Noun'), ('유기화학', 'Noun'), ('생화학', 'Noun'), ('식품화학', 'Noun'), ('등등', 'Noun'), ('화학', 'Noun'), ('이', 'Josa'), ('안', 'VerbPrefix'), ('쓰이는', 'Verb'), ('곳', 'Noun'), ('이', 'Josa'), ('없다', 'Adjective'), ('대학교', 'Noun'), ('에', 'Josa'), ('공부', 'Noun'), ('만', 'Josa'), ('하다', 'Verb'), ('졸업', 'Noun'), ('하고', 'Josa'), ('취업', 'Noun'), ('하러', 'Verb'), ('온것만이', 'Verb'), ('아닌데', 'Adjective'), ('남자', 'Noun'), ('가', 'Josa'), ('없네요', 'Adjective'), ('이리', 'Adverb'), ('봐도', 'Verb'), ('저리', 'Noun'), ('봐도', 'Verb'), ('남자', 'Noun'), ('가', 'Josa'), ('남자', 'Noun'), ('사람', 'Noun'), ('이', 'Josa'), ('없네요', 'Adjective'), ('피트', 'Noun'), ('생', 'Noun'), ('들', 'Suffix'), ('공부', 'Noun'), ('잘', 'VerbPrefix'), ('함', 'Verb'), ('정말', 'Noun'), ('많이', 'Adverb'), ('잘', 'VerbPrefix'), ('함', 'Verb'), ('피트', 'Noun'), ('과목', 'Noun'), ('에', 'Josa'), ('생물', 'Noun'), ('있어서', 'Adjective'), ('그런지', 'Adjective'), ('수업', 'Noun'), ('안', 'VerbPrefix'), ('들어도', 'Verb'), ('이미', 'Adverb'), ('알', 'Noun'), ('고', 'Josa'), ('있음', 'Adjective'), ('외울거', 'Verb'), ('많음', 'Adjective'), ('애매한', 'Adjective'), ('학과', 'Noun'), ('라서', 'Josa'), ('인체', 'Noun'), ('도', 'Josa'), ('배우고', 'Verb'), ('동물', 'Noun'), ('도', 'Josa'), ('배우고', 'Verb'), ('식물', 'Noun'), ('도', 'Josa'), ('배움', 'Noun'), ('얕게', 'Adjective'), ('많이', 'Adverb'), ('배운다고', 'Verb'), ('알', 'Noun'), ('면', 'Josa'), ('클', 'Verb'), ('남', 'Noun'), ('물리', 'Noun'), ('치료', 'Noun'), ('학과', 'Noun'), ('만큼', 'Noun'), ('근육', 'Noun'), ('과', 'Josa'), ('뼈', 'Noun'), ('를', 'Josa'), ('외움', 'Verb'), ('여자', 'Noun'), ('가', 'Josa'), ('너무', 'Adverb'), ('많다', 'Adjective'), ('너무', 'Adverb'), ('어려운', 'Adjective'), ('내용', 'Noun'), ('을', 'Josa'), ('많이', 'Adverb'), ('배우고', 'Verb'), ('의대', 'Noun'), ('에', 'Josa'), ('온건', 'Noun'), ('지', 'Josa'), ('간호', 'Noun'), ('학과', 'Noun'), ('인지', 'Josa'), ('보건관리', 'Noun'), ('학관', 'Noun'), ('지', 'Josa'), ('알', 'Noun'), ('수', 'Noun'), ('가', 'Verb'), ('없다', 'Adjective'), ('잘', 'Verb'), ('모르겠습니다', 'Verb'), ('정문', 'Noun'), ('에서', 'Josa'), ('조금', 'Noun'), ('먼', 'Adjective'), ('위치', 'Noun'), ('의', 'Josa'), ('과학관', 'Noun'), ('과', 'Noun'), ('보다는', 'Josa'), ('학교', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('불만', 'Noun'), ('이', 'Josa'), ('클거에요', 'Verb'), ('학과', 'Noun'), ('보단', 'Josa'), ('학교', 'Noun'), ('의', 'Josa'), ('단점', 'Noun'), ('이', 'Josa'), ...

# %%
#제외할 단어 추가
stop_words = "삼육대 단점 교수 학교 학과" #추가할 때 띄어쓰기로 추가해주기
stop_words = set(stop_words.split(' '))
# 불용어를 제외한 단어만 남기기
n_adj = [word for word in n_adj if not word in stop_words]
n_adj
#가장 많이 나온 단어 100개 저장
counts = Counter(n_adj)
tags = counts.most_common(100)
tags
# Out:
# [('종교', 58),
#  ('생각', 38),
#  ('없다', 35),
#  ('수업', 33),
#  ('학생', 25),
#  ('때문', 24),
#  ('있다', 24),
#  ('전공', 22),
#  ('취업', 22),
#  ('진짜', 22),
#  ('채플', 21),
#  ('공부', 19),
#  ('과제', 18),
#  ('정말', 18),
#  ('강요', 17),
#  ('있는', 17),
#  ('과목', 16),
#  ('학식', 16),
#  ('정도', 16),
#  ('그냥', 15),
#  ('학점', 15),
#  ('없음', 15),
#  ('사람', 14),
#  ('없는', 14),
#  ('고기', 14),
#  ('건물', 14),
#  ('서울', 14),
#  ('필수', 14),
#  ('많다', 13),
#  ('대학', 13),
#  ('별로', 13),
#  ('대한', 12),
#  ('같은', 12),
#  ('빡세', 12),
#  ('디자인', 11),
#  ('영어', 11),
#  ('후문', 11),
#  ('없고', 11),
#  ('매우', 11),
#  ('조금', 10),
#  ('준비', 10),
#  ('학기', 10),
#  ('끼리', 10),
#  ('자기', 10),
#  ('강의', 10),
#  ('있는데', 10),
#  ('여기', 10),
#  ('절대', 9),
#  ('있음', 9),
#  ('우리', 9),
#  ('많은', 9),
#  ('제대로', 9),
#  ('다른', 9),
#  ('주변', 9),
#  ('수준', 9),
#  ('졸업', 8),
#  ('많음', 8),
#  ('시험', 8),
#  ('느낌', 8),
#  ('학년', 8),
#  ('좋은', 8),
#  ('한번', 8),
#  ('있습니다', 8),
#  ('라면', 8),
#  ('시설', 8),
#  ('친구', 8),
#  ('대학교', 7),
#  ('커리큘럼', 7),
#  ('병원', 7),
#  ('군기', 7),
#  ('거나', 7),
#  ('교육', 7),
#  ('선배', 7),
#  ('없어서', 7),
#  ('아닌', 7),
#  ('리뷰', 7),
#  ('담배', 7),
#  ('자체', 7),
#  ('하나', 6),
#  ('문제', 6),
#  ('같다', 6),
#  ('다만', 6),
#  ('부분', 6),
#  ('있어서', 6),
#  ('체육대회', 6),
#  ('힘들다', 6),
#  ('좋지', 6),
#  ('인식', 6),
#  ('깊게', 6),
#  ('편입', 6),
#  ('축제', 6),
#  ('경우', 6),
#  ('입니다', 6),
#  ('시간', 6),
#  ('이상', 6),
#  ('안되고', 6),
#  ('보고', 6),
#  ('노작', 6),
#  ('내용', 5),
#  ('미술', 5)]

# %%
path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
word_cloud = WordCloud(font_path=path, background_color='black',max_font_size=400,colormap='coolwarm').generate_from_frequencies(dict(tags))

# 사이즈 설정 및 화면에 출력
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.imshow(word_cloud)
plt.axis('off')
#워드클라우드 사진으로 저장
plt.savefig('애드캠퍼스_단점.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 학교에 바라는 점

# %%
wish_text = ''
for temp in df[' 학교에 바라는 점 ']:
    wish_text += str(temp)
wish_text = re.sub(r'[^가-힣a-zA-Z0-9]',' ',wish_text)
wish_text
# Out:
# '과제좀 조금만 내줬으면 좋겠음  솔직히 양심없음여자좀 많이 들어왔으면 좋겠고  통폐합은 하지 않았으면  이건 우리학부 뿐만 아니라 학교에다 바라는건데 학교가 너무 노잼입니다  학지처는 각성하라지금 배우는 것에 만족스럽게 다니고 있다  하지만 보다 외우기 보다는 이해할 수 있는 학문이 되었으면 좋을 것 같다 학과보단 학교에 바라는 것이 있다  식영과 지원 좀 팍팍 해줘라전국에 있는 모든 우리 예비영양사들 훌륭한 영양사 될 수 있도록 잘 보듬어 주세요피트 볼꺼면 화학과로 가줘 친구들아 과제가 너무 많다  감당하기 힘들다과에 대해 더 자세히 알려주고 과에 관련한 진로를 더 자세히 알려줬으면 좋겠다 앞으로 잘 부탁드립니다없다부수적인 돈이 너무 많이 들어간다 공부를 너무 열심히 한다 과방 있었으면 좋겠다수강인원을 많이 늘려줬으면 좋겠다학과 자체의 취업연계프로그램이 부실하다과제가 너무 많다  감당하기 힘들다없다남녀가 좀 같이 놀았으면 좋겠다  대학로 개발좀 했으면통폐합 할거면 카메과를 없애든가 시대를 역행하고 있어  남들은 공대늘릴려고 난리인데교회안에 학교가 있는 것이라서 공부 더해서 좋은 학교 가라유치원 교사를 위한 스트레스 해소와 업무환경을 개선할 필요가 있다경영정보가 어쨌든 인문계열이니 경영쪽으로 좀만 더 힘써주길없다각종행사 체육대회 연습 은근한 강요 실험시 보수공사  온실에 쇼파좀 늘려줬으면 한다학과 커뮤니티가 활성화되면 좋겠음  싸이월드 클럽이 있긴 하지만 거기는 자료 올리는 곳일 뿐이고 대화는 없음  그리고 멘토 멘티 프로그램 진행되면 좋겠음  난 이제 4학년 되지만 멘토 멘티 하면 1학년 모의수업할 때 도움도 줄 수 있고  친목도모도 가능하고  좋은 점이 많을 것 같음인원이 적은데 35명중에 학과 봉사활동 동아리를 만들었음 좋겠습니다 사회복지학부 였다가 과가 생긴지 얼마 되진 않아서 신입생들은 진로 에 대한 두려움이 많으니 더 많은 정보 제공이 있었으면 좋겠고 학회끼리 친한것보다 두루두루 친한 학과가 되었으면 좋겠음 교수님 시험 좀 참신하게 내셨으면    
# %%
# Okt 함수를 이용해 형태소 분석
okt = Okt()
w_list =[]

w_list = okt.pos(wish_text)

print(w_list)

n_adj =[]
# 명사 또는 형용사인 단어만 n_adj에 넣어주기
for word, tag in w_list:
    if tag in ['Noun','Adjective']:
        if len(word) > 1:
            n_adj.append(word)
# Out:
# [('과제', 'Noun'), ('좀', 'Noun'), ('조금', 'Noun'), ('만', 'Josa'), ('내줬으면', 'Verb'), ('좋겠음', 'Adjective'), ('솔직히', 'Adjective'), ('양심', 'Noun'), ('없음', 'Adjective'), ('여자', 'Noun'), ('좀', 'Noun'), ('많이', 'Adverb'), ('들어왔으면', 'Verb'), ('좋겠고', 'Adjective'), ('통폐합', 'Noun'), ('은', 'Josa'), ('하지', 'Verb'), ('않았으면', 'Verb'), ('이건', 'Noun'), ('우리', 'Noun'), ('학부', 'Noun'), ('뿐', 'Noun'), ('만', 'Josa'), ('아니라', 'Adjective'), ('학교', 'Noun'), ('에다', 'Josa'), ('바라는건데', 'Verb'), ('학교', 'Noun'), ('가', 'Josa'), ('너무', 'Adverb'), ('노잼', 'Noun'), ('입니다', 'Adjective'), ('학', 'Noun'), ('지', 'Josa'), ('처', 'Noun'), ('는', 'Josa'), ('각성', 'Noun'), ('하', 'Suffix'), ('라지', 'Josa'), ('금', 'Noun'), ('배우는', 'Verb'), ('것', 'Noun'), ('에', 'Josa'), ('만족', 'Noun'), ('스럽게', 'Josa'), ('다니고', 'Verb'), ('있다', 'Adjective'), ('하지만', 'Conjunction'), ('보다', 'Verb'), ('외우기', 'Verb'), ('보다는', 'Josa'), ('이해', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있는', 'Adjective'), ('학문', 'Noun'), ('이', 'Josa'), ('되었으면', 'Verb'), ('좋을', 'Adjective'), ('것', 'Noun'), ('같다', 'Adjective'), ('학과', 'Noun'), ('보단', 'Josa'), ('학교', 'Noun'), ('에', 'Josa'), ('바라는', 'Verb'), ('것', 'Noun'), ('이', 'Josa'), ('있다', 'Adjective'), ('식영', 'Noun'), ('과', 'Josa'), ('지원', 'Noun'), ('좀', 'Noun'), ('팍팍', 'Adverb'), ('해줘라', 'Verb'), ('전국', 'Noun'), ('에', 'Josa'), ('있는', 'Adjective'), ('모든', 'Noun'), ('우리', 'Noun'), ('예비', 'Noun'), ('영양사', 'Noun'), ('들', 'Suffix'), ('훌륭한', 'Adjective'), ('영양사', 'Noun'), ('될', 'Verb'), ('수', 'Noun'), ('있도록', 'Adjective'), ('잘', 'Verb'), ('보듬어', 'Verb'), ('주세요', 'Verb'), ('피트', 'Noun'), ('볼꺼면', 'Verb'), ('화학', 'Noun'), ('과로', 'Noun'), ('가줘', 'Verb'), ('친구', 'Noun'), ('들', 'Suffix'), ('아', 'Josa'), ('과제', 'Noun'), ('가', 'Josa'), ('너무', 'Adverb'), ('많다', 'Adjective'), ('감당', 'Noun'), ('하기', 'Verb'), ('힘들', 'Adjective'), ('다과', 'Noun'), ('에', 'Josa'), ('대해', 'Noun'), ('더', 'Noun'), ('자세히', 'Adjective'), ('알려주고', 'Verb'), ('과', 'Noun'), ('에', 'Josa'), ('관련', 'Noun'), ('한', 'Josa'), ('진로', 'Noun'), ('를', 'Josa'), ('더', 'Noun'), ('자세히', 'Adjective'), ('알려', 'Verb'), ('줬으면', 'Verb'), ('좋겠다', 'Adjective'), ('앞', 'Noun'), ('으로', 'Josa'), ('잘', 'Verb'), ('부탁드립니다', 'Adjective'), ('없다', 'Adjective'), ('부수', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('돈', 'Noun'), ('이', 'Josa'), ('너무', 'Adverb'), ('많이', 'Adverb'), ('들어간다', 'Verb'), ('공부', 'Noun'), ('를', 'Josa'), ('너무', 'Adverb'), ('열심히', 'Adverb'), ('한다', 'Verb'), ('과방', 'Noun'), ('있었으면', 'Adjective'), ('좋겠다수', 'Adjective'), ('강인원', 'Noun'), ('을', 'Josa'), ('많이', 'Adverb'), ('늘려', 'Verb'), ('줬으면', 'Verb'), ('좋겠다', 'Adjective'), ('학과', 'Noun'), ('자체', 'Noun'), ('의', 'Josa'), ('취업', 'Noun'), ('연', 'Modifier'), ('계', 'Noun'), ('프로그램', 'Noun'), ('이', 'Josa'), ('부실하다', 'Adjective'), ('과제', 'Noun'), ('가', 'Josa'), ('너무', 'Adverb'), ('많다', 'Adjective'), ('감당', 'Noun'), ('하기', 'Verb'), ('힘들다', 'Adjective'), ('없다', 'Adjective'), ('남녀', 'Noun'), ('가', 'Josa'), ('좀', 'Noun'), ('같이', 'Adverb'), ('놀았으면', 'Verb'), ('좋겠다', 'Adjective'), ('대학로', 'Noun'), ('개발', 'Noun'), ('좀', 'Noun'), ('했으면', 'Verb'), ('통폐합', 'Noun'), ('할거면', 'Verb'), ('카메', 'Noun'), ('과를', 'Josa'), ('없애든가', 'Verb'), ('시대', 'Noun'), ('를', 'Josa'), ('역행', 'Noun'), ('하고', 'Josa'), ('있어', 'Adjective'), ('남', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('공대', 'Noun'), ('늘릴려고', 'Verb'), ('난리', 'Noun'), ('인데', 'Josa'), ('교회', 'Noun'), ('안', 'Noun'), ('에', 'Josa'), ('학교', 'Noun'), ('가', 'Josa'), ('있는', 'Adjective'), ('것', 'Noun'), ('이라서', 'Josa'), ('공부', 'Noun'), ('더해서', 'Adjective'), ('좋은', 'Adjective'), ('학교', 'Noun'), ('가라', 'Noun'), ('유치원', 'Noun'), ('교사', 'Noun'), ('를', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('스트레스', 'Noun'), ('해소', 'Noun'), ('와', 'Josa'), ('업무', 'Noun'), ('환경', 'Noun'), ('을', 'Josa'), ('개선', 'Noun'), ('할', 'Verb'), ('필요', 'Noun'), ('가', 'Josa'), ('있다', 'Adjective'), ('경영정보', 'Noun'), ('가', 'Josa'), ('어쨌든', 'Noun'), ('인문', 'Noun'), ('계열', 'Noun'), ('이니', 'Josa'), ('경', 'Modifier'), ('영', 'Modifier'), ('쪽', 'Noun'), ('으로', 'Josa'), ('좀', 'Noun'), ('만', 'Josa'), ('더', 'Noun'), (' ...

# %%
#제외할 단어 추가
stop_words = "삼육대 교수 학교 학과 좋겠다" #추가할 때 띄어쓰기로 추가해주기
stop_words = set(stop_words.split(' '))
# 불용어를 제외한 단어만 남기기
n_adj = [word for word in n_adj if not word in stop_words]
n_adj
#가장 많이 나온 단어 100개 저장
counts = Counter(n_adj)
tags = counts.most_common(100)
tags
# Out:
# [('종교', 20),
#  ('생각', 18),
#  ('학생', 15),
#  ('없다', 13),
#  ('있는', 12),
#  ('수업', 12),
#  ('딱히', 12),
#  ('강요', 9),
#  ('좋겠음', 8),
#  ('없음', 8),
#  ('지원', 8),
#  ('영어', 8),
#  ('진짜', 8),
#  ('없는', 8),
#  ('좋겠습니다', 7),
#  ('때문', 7),
#  ('사람', 7),
#  ('친구', 6),
#  ('개선', 6),
#  ('채플', 6),
#  ('조금', 5),
#  ('좋을', 5),
#  ('자체', 5),
#  ('취업', 5),
#  ('좋은', 5),
#  ('필요', 5),
#  ('같음', 5),
#  ('장학금', 5),
#  ('강의', 5),
#  ('과목', 5),
#  ('전공', 5),
#  ('제발', 5),
#  ('운영', 5),
#  ('시간', 5),
#  ('시간표', 5),
#  ('미대', 5),
#  ('대학', 5),
#  ('우리', 4),
#  ('학문', 4),
#  ('진로', 4),
#  ('있었으면', 4),
#  ('대한', 4),
#  ('문제', 4),
#  ('필수', 4),
#  ('학기', 4),
#  ('등록금', 4),
#  ('고기', 4),
#  ('커리큘럼', 4),
#  ('정말', 4),
#  ('부분', 4),
#  ('과제', 3),
#  ('학부', 3),
#  ('아니라', 3),
#  ('입니다', 3),
#  ('있다', 3),
#  ('같다', 3),
#  ('모든', 3),
#  ('많다', 3),
#  ('대해', 3),
#  ('부탁드립니다', 3),
#  ('공부', 3),
#  ('프로그램', 3),
#  ('환경', 3),
#  ('계열', 3),
#  ('보수', 3),
#  ('학년', 3),
#  ('학회', 3),
#  ('끼리', 3),
#  ('시험', 3),
#  ('재수', 3),
#  ('있음', 3),
#  ('수준', 3),
#  ('졸업', 3),
#  ('거의', 3),
#  ('시설', 3),
#  ('교양', 3),
#  ('어떻게', 3),
#  ('다른', 3),
#  ('그냥', 3),
#  ('학식', 3),
#  ('다양한', 3),
#  ('없습니다', 3),
#  ('없고', 3),
#  ('애정도', 3),
#  ('여자', 2),
#  ('좋겠고', 2),
#  ('통폐합', 2),
#  ('이건', 2),
#  ('만족', 2),
#  ('이해', 2),
#  ('영양사', 2),
#  ('감당', 2),
#  ('힘들', 2),
#  ('자세히', 2),
#  ('관련', 2),
#  ('과방', 2),
#  ('힘들다', 2),
#  ('시대', 2),
#  ('공대', 2),
#  ('교회', 2)]

# %%
path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
word_cloud = WordCloud(font_path=path, background_color='black',max_font_size=400,colormap='coolwarm').generate_from_frequencies(dict(tags))

# 사이즈 설정 및 화면에 출력
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.imshow(word_cloud)
plt.axis('off')
#워드클라우드 사진으로 저장
plt.savefig('애드캠퍼스_바라는점.png', bbox_inches='tight')
plt.show()
